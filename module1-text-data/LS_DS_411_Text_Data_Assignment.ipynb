# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>
# <br></br>
# <br></br>
#
# # Natural Language Processing (NLP)
# ## *Data Science Unit 4 Sprint 1 Assignment 1*
#
# Your goal in this assignment: find the attributes of the best & worst coffee shops in the dataset. The text is fairly raw: dates in the review, extra words in the `star_rating` column, etc. You'll probably want to clean that stuff up for a better analysis.
#
# Analyze the corpus of text using text visualizations of token frequency. Try cleaning the data as much as possible. Try the following techniques:
# - Lemmatization
# - Custom stopword removal
#
# Keep in mind the attributes of good tokens. Once you have a solid baseline, layer in the star rating in your visualization(s). Key part of this assignment - produce a write-up of the attributes of the best and worst coffee shops. Based on your analysis, what makes the best the best and the worst the worst. Use graphs and numbesr from your analysis to support your conclusions. There should be plenty of markdown cells! :coffee:

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('Jml7NVYm8cs')

# %%
# %pwd
# Out:
# 'C:\\Users\\David.000\\Desktop\\Lambda\\U4\\DS-Unit-4-Sprint-1-NLP\\module1-text-data'

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/LambdaSchool/DS-Unit-4-Sprint-1-NLP/master/module1-text-data/data/yelp_coffeeshop_review_data.csv"

shops = pd.read_csv(url)
shops.head()
# Out:
#                   coffee_shop_name  \
# 0  The Factory - Cafe With a Soul
# 1  The Factory - Cafe With a Soul
# 2  The Factory - Cafe With a Soul
# 3  The Factory - Cafe With a Soul
# 4  The Factory - Cafe With a Soul
#
#                                     full_review_text        star_rating
# 0   11/25/2016 1 check-in Love love loved the atm...   5.0 star rating
# 1   12/2/2016 Listed in Date Night: Austin, Ambia...   4.0 star rating
# 2   11/30/2016 1 check-in Listed in Brunch Spots ...   4.0 star rating
# 3   11/25/2016 Very cool decor! Good drinks Nice ...   2.0 star rating
# 4   12/3/2016 1 check-in They are located within ...   4.0 star rating

# %%
shops.shape
# Out:
# (7616, 3)

# %%
strang = shops['star_rating'][0]
strang[1]
# Out:
# '5'

# %%
shops['rating'] = shops['star_rating'].apply(lambda x: int(x[1])-3)
shops[['rating']]
# Out:
#       rating
# 0          2
# 1          1
# 2          1
# 3         -1
# 4          1
# ...      ...
# 7611       1
# 7612       2
# 7613       1
# 7614       0
# 7615       1
#
# [7616 rows x 1 columns]

# %%
shops.head()
# Out:
#                   coffee_shop_name  \
# 0  The Factory - Cafe With a Soul
# 1  The Factory - Cafe With a Soul
# 2  The Factory - Cafe With a Soul
# 3  The Factory - Cafe With a Soul
# 4  The Factory - Cafe With a Soul
#
#                                     full_review_text        star_rating  \
# 0   11/25/2016 1 check-in Love love loved the atm...   5.0 star rating
# 1   12/2/2016 Listed in Date Night: Austin, Ambia...   4.0 star rating
# 2   11/30/2016 1 check-in Listed in Brunch Spots ...   4.0 star rating
# 3   11/25/2016 Very cool decor! Good drinks Nice ...   2.0 star rating
# 4   12/3/2016 1 check-in They are located within ...   4.0 star rating
#
#    rating
# 0       2
# 1       1
# 2       1
# 3      -1
# 4       1

# %%
import seaborn as sns
import spacy
from spacy.tokenizer import Tokenizer
import re

# %%
nlp = spacy.load('en_core_web_lg')
tokenizer = Tokenizer(nlp.vocab)

# %%
tokens = []

for doc in tokenizer.pipe(shops['full_review_text']):

    doc_tokens = []
    
    for token in doc:
        if (token.is_stop == False) & (token.is_punct == False):
            lolo = re.sub('[^a-zA-Z]', '', token.text).lower()
        if lolo not in nlp.Defaults.stop_words:
            doc_tokens.append(lolo)
            
    tokens.append(doc_tokens)

shops['tokens'] = tokens
shops.head()
# Out:
#                   coffee_shop_name  \
# 0  The Factory - Cafe With a Soul
# 1  The Factory - Cafe With a Soul
# 2  The Factory - Cafe With a Soul
# 3  The Factory - Cafe With a Soul
# 4  The Factory - Cafe With a Soul
#
#                                     full_review_text        star_rating  \
# 0   11/25/2016 1 check-in Love love loved the atm...   5.0 star rating
# 1   12/2/2016 Listed in Date Night: Austin, Ambia...   4.0 star rating
# 2   11/30/2016 1 check-in Listed in Brunch Spots ...   4.0 star rating
# 3   11/25/2016 Very cool decor! Good drinks Nice ...   2.0 star rating
# 4   12/3/2016 1 check-in They are located within ...   4.0 star rating
#
#    rating                                             tokens
# 0       2  [, , , checkin, love, love, loved, loved, atmo...
# 1       1  [, , listed, listed, date, night, austin, ambi...
# 2       1  [, , , checkin, listed, listed, brunch, spots,...
# 3      -1  [, , , cool, decor, good, drinks, nice, seatin...
# 4       1  [, , , checkin, checkin, checkin, located, loc...

# %%
shops.tokens.head()
# Out:
# 0    [, , , checkin, love, love, loved, loved, atmo...
# 1    [, , listed, listed, date, night, austin, ambi...
# 2    [, , , checkin, listed, listed, brunch, spots,...
# 3    [, , , cool, decor, good, drinks, nice, seatin...
# 4    [, , , checkin, checkin, checkin, located, loc...
# Name: tokens, dtype: object

# %%
# import re

# sample = shops['full_review_text'][0]

# re.sub('[^a-zA-Z 0-9]', '', sample)

# %%
shops[['full_review_text','tokens']].head()
# Out:
#                                     full_review_text  \
# 0   11/25/2016 1 check-in Love love loved the atm...
# 1   12/2/2016 Listed in Date Night: Austin, Ambia...
# 2   11/30/2016 1 check-in Listed in Brunch Spots ...
# 3   11/25/2016 Very cool decor! Good drinks Nice ...
# 4   12/3/2016 1 check-in They are located within ...
#
#                                               tokens
# 0  [, , , checkin, love, love, loved, loved, atmo...
# 1  [, , listed, listed, date, night, austin, ambi...
# 2  [, , , checkin, listed, listed, brunch, spots,...
# 3  [, , , cool, decor, good, drinks, nice, seatin...
# 4  [, , , checkin, checkin, checkin, located, loc...

# %%
from collections import Counter

# %%
def count(docs):
    word_counts = Counter()
    appears_in = Counter()
    
    total_docs = len(docs)
    
    for doc in docs:
        word_counts.update(doc)
        appears_in.update(set(doc))
    
    temp = zip(word_counts.keys(), word_counts.values())
    
    wc = pd.DataFrame(temp, columns = ['word', 'count'])
    
    wc['rank'] = wc['count'].rank(
        method='first', ascending=False
    )
    total = wc['count'].sum()
    
    wc['pct_total'] = wc['count'].apply(
        lambda x: x/total
    )
    
    wc = wc.sort_values(by='rank')
    wc['cul_pct_total'] = wc['pct_total'].cumsum()
    
    t2 = zip(appears_in.keys(), appears_in.values())
    ac = pd.DataFrame(t2, columns=['word', 'appears_in'])
    wc = ac.merge(wc, on='word')
    
    wc['appears_in_pct'] = wc['appears_in'].apply(
       lambda x: x/total_docs 
    )
    
    return wc.sort_values(by='rank')

# %%
wc = count(shops['tokens'])
wc.head(20)
# Out:
#          word  appears_in  count  rank  pct_total  cul_pct_total  \
# 0                    7616  63203   1.0   0.082399       0.082399
# 8      coffee        4877  18334   2.0   0.023902       0.106301
# 129     place        3659  12626   3.0   0.016461       0.122762
# 151      good        2788   6647   4.0   0.008666       0.131427
# 169      like        2124   6123   5.0   0.007983       0.139410
# 66      great        2836   5436   6.0   0.007087       0.146497
# 43     austin        1788   4144   7.0   0.005403       0.151900
# 495      time        1469   4023   8.0   0.005245       0.157145
# 3        love        1500   3784   9.0   0.004933       0.162078
# 13       shop        1331   3639  10.0   0.004744       0.166822
# 19      latte        1128   3541  11.0   0.004616       0.171438
# 37    checkin        1960   3534  12.0   0.004607       0.176046
# 297       ive        1188   3529  13.0   0.004601       0.180647
# 365      food        1365   3501  14.0   0.004564       0.185211
# 261        im        1418   3401  15.0   0.004434       0.189645
# 463      come        1056   3359  16.0   0.004379       0.194024
# 183  friendly        1577   3054  17.0   0.003982       0.198006
# 473    people        1163   2871  18.0   0.003743       0.201749
# 475     staff        1201   2870  19.0   0.003742       0.205490
# 50       nice        1463   2862  20.0   0.003731       0.209221
#
#      appears_in_pct
# 0          1.000000
# 8          0.640362
# 129        0.480436
# 151        0.366071
# 169        0.278887
# 66         0.372374
# 43         0.234769
# 495        0.192883
# 3          0.196954
# 13         0.174764
# 19         0.148109
# 37         0.257353
# 297        0.155987
# 365        0.179228
# 261        0.186187
# 463        0.138655
# 183        0.207064
# 473        0.152705
# 475        0.157694
# 50         0.192096

# %%
stop_jargon = [
    '','coffee','place','austin','latte','checkin','ive','im','people',
    'shop','little','tea','got','food','drink','ice','know','day',
    'breakfast','milk'
]

# %%
STOP_WORDS = nlp.Defaults.stop_words.union(stop_jargon)

# %%
tokens = []

for doc in tokenizer.pipe(shops['full_review_text']):
    
    doc_tokens = []
    
    for token in doc:
        lolo = re.sub('[^a-zA-Z]', '', token.lemma_).lower()
        if lolo not in STOP_WORDS:
            doc_tokens.append(lolo)
   
    tokens.append(doc_tokens)
    
shops['tokens'] = tokens
wc = count(shops['tokens'])
print(wc.shape)
wc.head(40)
# Out:
# (17753, 7)
#             word  appears_in  count  rank  pct_total  cul_pct_total  \
# 140         good        3111   4668   1.0   0.015000       0.015000
# 56         great        2851   3941   2.0   0.012664       0.027663
# 155         like        2251   3333   3.0   0.010710       0.038373
# 425         come        1847   2476   4.0   0.007956       0.046330
# 3           love        1753   2290   5.0   0.007358       0.053688
# 448         time        1670   2229   6.0   0.007162       0.060851
# 86           try        1609   2043   7.0   0.006565       0.067415
# 1          order        1369   2005   8.0   0.006443       0.073858
# 40          nice        1496   1785   9.0   0.005736       0.079594
# 599         work        1413   1780  10.0   0.005720       0.085314
# 168     friendly        1598   1684  11.0   0.005411       0.090725
# 282         dont        1156   1432  12.0   0.004601       0.095326
# 708    delicious        1261   1402  13.0   0.004505       0.099831
# 152      service        1204   1376  14.0   0.004422       0.104253
# 6         pretty        1081   1366  15.0   0.004389       0.108642
# 434        staff        1205   1304  16.0   0.004190       0.112832
# 91          want         977   1179  17.0   0.003788       0.116621
# 61           lot         995   1176  18.0   0.003779       0.120400
# 48    definitely        1013   1156  19.0   0.003715       0.124114
# 16          find         957   1130  20.0   0.003631       0.127745
# 107         spot         941   1127  21.0   0.003621       0.131367
# 374        taste         903   1125  22.0   0.003615       0.134982
# 210        think         905   1109  23.0   0.003564       0.138545
# 455         look         925   1102  24.0   0.003541       0.142086
# 78        flavor         758   1053  25.0   0.003384       0.145470
# 119         seat         870   1047  26.0   0.003364       0.148834
# 83         sweet         790    989  27.0   0.003178       0.152012
# 5     atmosphere         902    969  28.0   0.003114       0.155126
# 555        small         813    962  29.0   0.003091       0.158217
# 143         feel         804    955  30.0   0.003069       0.161286
# 84          park         717    936  31.0   0.003008       0.164294
# 144        table         738    915  32.0   0.002940       0.167234
# 205       friend         765    911  33.0   0.002927       0.170161
# 213        super         774    885  34.0   0.002844       0.173005
# 625        thing         753    879  35.0   0.002825       0.175829
# 513          cup         695    853  36.0   0.002741       0.178570
# 215          sit         730    848  37.0   0.002725       0.181295
# 93         enjoy         742    846  38.0   0.002718       0.184014
# 587     espresso         644    845  39.0   0.002715       0.186729
# 1340       cream         470    840  40.0   0.002699       0.189428
#
#       appears_in_pct
# 140         0.408482
# 56          0.374343
# 155         0.295562
# 425         0.242516
# 3           0.230173
# 448         0.219275
# 86          0.211266
# 1           0.179753
# 40          0.196429
# 599         0.185530
# 168         0.209821
# 282         0.151786
# 708         0.165572
# 152         0.158088
# 6           0.141938
# 434         0.158220
# 91          0.128283
# 61          0.130646
# 48          0.133009
# 16          0.125657
# 107         0.123556
# 374         0.118566
# 210         0.118829
# 455         0.121455
# 78          0.099527
# 119         0.114233
# 83          0.103729
# 5           0.118435
# 555         0.106749
# 143         0.105567
# 84          0.094144
# 144         0.096901
# 205         0.100446
# 213         0.101628
# 625         0.098871
# 513         0.091255
# 215         0.095851
# 93          0.097426
# 587         0.084559
# 1340        0.061712

# %%
fives = shops[shops['rating']==2]
print('fives:', fives.shape[0])

fours = shops[shops['rating']==1]
print('fours:', fours.shape[0])

threes = shops[shops['rating']==0]
print('threes:', threes.shape[0])

twos = shops[shops['rating']==-1]
print('twos:', twos.shape[0])

ones = shops[shops['rating']==-2]
print('ones:', ones.shape[0])
# Out:
# fives: 3780
# fours: 2360
# threes: 738
# twos: 460
# ones: 278

# %%
star_levels = [fives,fours,threes,twos,ones]

# wc = count(star_levels[0]['tokens'])
# words0 = wc['word']
# words0

for x in range(5):
    wc = count(star_levels[x]['tokens'])
    name = 'word' + str(x)
    vars()[name] = wc['word'].reset_index(drop=True)
    pct = 'pct' + str(x)
    vars()[pct] = wc['pct_total'].reset_index(drop=True)
    print(vars()[pct].shape)
# Out:
# (11293,)
# (9872,)
# (5234,)
# (4162,)
# (3068,)

# %%
wtf = count(fives['tokens'])
wtf.head()
# Out:
#       word  appears_in  count  rank  pct_total  cul_pct_total  appears_in_pct
# 275  great        1559   2180   1.0   0.015827       0.015827        0.412434
# 38    good        1310   1883   2.0   0.013671       0.029498        0.346561
# 3     love        1075   1445   3.0   0.010491       0.039989        0.284392
# 102   like         891   1260   4.0   0.009148       0.049137        0.235714
# 142   come         809   1025   5.0   0.007442       0.056578        0.214021

# %%
by_rating = pd.DataFrame({
    'fives':word0.head(3068),
    'fives_pct':pct0.head(3068),
    'fours':word1.head(3068),
    'fours_pct':pct1.head(3068),
    'threes':word2.head(3068),
    'threes_pct':pct2.head(3068),
    'twos':word3.head(3068),
    'twos_pct':pct3.head(3068),
    'ones':word4,
    'ones_pct':pct4.head(3068)
})

by_rating.head(20)
# Out:
#          fives  fives_pct       fours  fours_pct   threes  threes_pct  \
# 0        great   0.015827        good   0.017112     good    0.017083
# 1         good   0.013671       great   0.012318     like    0.013424
# 2         love   0.010491        like   0.010915     come    0.008556
# 3         like   0.009148        come   0.007974    order    0.007937
# 4         come   0.007442         try   0.007019    great    0.007818
# 5     friendly   0.007100        time   0.006723     time    0.007612
# 6         time   0.006941        nice   0.006713     nice    0.007022
# 7    delicious   0.006549       order   0.006083   pretty    0.006963
# 8          try   0.006512        work   0.006045     dont    0.006727
# 9         work   0.005532        love   0.005672      try    0.006166
# 10       staff   0.005300      pretty   0.005605     work    0.005399
# 11        nice   0.005264    friendly   0.004832    taste    0.005075
# 12       order   0.004821        dont   0.004593  service    0.004868
# 13  definitely   0.004305         lot   0.004498     love    0.004721
# 14     service   0.004189        seat   0.004173    think    0.004573
# 15      gelato   0.004073        spot   0.004173     look    0.004514
# 16      flavor   0.003964        park   0.004106     feel    0.004455
# 17    favorite   0.003957   delicious   0.003934    didnt    0.004190
# 18        spot   0.003950  definitely   0.003925    small    0.004101
# 19        find   0.003906       think   0.003877      lot    0.003983
#
#         twos  twos_pct      ones  ones_pct
# 0       like  0.013815     order  0.013469
# 1       good  0.013678      like  0.013314
# 2      order  0.011900   service  0.009908
# 3       come  0.009255      time  0.009598
# 4       time  0.008526      come  0.009521
# 5    service  0.006976      good  0.008824
# 6      great  0.006611       ask  0.007818
# 7       want  0.006201  customer  0.006812
# 8       dont  0.006018      dont  0.006502
# 9      taste  0.005882       try  0.006115
# 10      work  0.005836      work  0.005728
# 11       try  0.005608      tell  0.005496
# 12       ask  0.005334     think  0.005496
# 13      wait  0.004559     taste  0.005186
# 14     didnt  0.004468      look  0.005109
# 15    review  0.004286      want  0.005109
# 16     think  0.004149      rude  0.004954
# 17    pretty  0.004149     great  0.004722
# 18      look  0.004012     didnt  0.004335
# 19  customer  0.003875      wait  0.004335

# %%
# food = 'bread'+str(5)
# vars()[food] = 123
# print(bread5)
# Out:
# 123

# %% [markdown]
# ## How do we want to analyze these coffee shop tokens?
#
# - Overall Word / Token Count
# - View Counts by Rating
# - *Hint:* a 'bad' coffee shops has a rating betweeen 1 & 3 based on the distribution of ratings. A 'good' coffee shop is a 4 or 5.

# %%
tenwords = by_rating.head(10)

# %%
import squarify
import matplotlib.pyplot as plt

for x in range(5):
    squarify.plot(
        sizes=tenwords.iloc[:,((2*x)+1)],
        label=tenwords.iloc[:,(2*x)],
        alpha=.8
    )
    plt.axis('off')
    plt.title(tenwords.columns[2*x])
    plt.show()

# %%
# skewer = 
# .reset_index(drop=True)

# %% [markdown]
# ## Can visualize the words with the greatest difference in counts between 'good' & 'bad'?
#
# Couple Notes:
# - Rel. freq. instead of absolute counts b/c of different numbers of reviews
# - Only look at the top 5-10 words with the greatest differences

# %% [markdown]
# ## Stretch Goals
#
# * Analyze another corpus of documents - such as Indeed.com job listings ;).
# * Play with the Spacy API to
#  - Extract Named Entities
#  - Extracting 'noun chunks'
#  - Attempt Document Classification with just Spacy
#  - *Note:* This [course](https://course.spacy.io/) will be of interesting in helping you with these stretch goals.
# * Try to build a plotly dash app with your text data
